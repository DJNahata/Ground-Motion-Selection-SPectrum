# %%
import numpy as np
from sklearn import preprocessing, cross_validation, neighbors

print('dj1')
NGA_West2_Flatfile_RotD50_d050_public_version
# Out:
# dj1
# C:\Users\DHANANJAY\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# !pip install pandas
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 18.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
pwd
# Out:
# 'C:\\Users\\DHANANJAY'

# %%
cd E:\Dhananjay Study\Masters Folder\Datasets of Ground Motion Spectrum Project
# Out:
# E:\Dhananjay Study\Masters Folder\Datasets of Ground Motion Spectrum Project

# %%
cd C:\Users\DHANANJAY
# Out:
# C:\Users\DHANANJAY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print('dj1')
# Out:
# dj1

# %%
wb_sales = pd.ExcelFile(r"E:\Dhananjay Study\Masters Folder\Datasets of Ground Motion Spectrum Project\NGA_West2_Flatfile_RotD50_d050_public_version.xlsx")

print('dj2')
# Out:
# dj2

# %%
sheet1 = pd.read_excel(r"E:\Dhananjay Study\Masters Folder\Datasets of Ground Motion Spectrum Project\NGA_West2_Flatfile_RotD50_d050_public_version.xlsx", sheetname=0)
read_sheet_name = wb_sales.sheet_names
read_sheet_name
# Out:
# C:\Users\DHANANJAY\Anaconda3\envs\cs231n\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# ['ROTD50_d050']

# %%
sheet1
# Out:
#        Record Sequence Number  EQID     Earthquake Name  YEAR  MODY  HRMN  \
# 0                           1     1  Helena, Montana-01  1935  1031  1838
# 1                           2     2  Helena, Montana-02  1935  1031  1918
# 2                           3     3         Humbolt Bay  1937   207   442
# 3                           4     4  Imperial Valley-01  1938   606   242
# 4                           5     5  Northwest Calif-01  1938   912   610
# 5                           6     6  Imperial Valley-02  1940   519   437
# 6                           7     7  Northwest Calif-02  1941   209   945
# 7                           8     8   Northern Calif-01  1941  1003  1614
# 8                           9     9             Borrego  1942  1021  1622
# 9                          10    10  Imperial Valley-03  1951   124   717
# 10                         11    11  Northwest Calif-03  1951  1008   411
# 11                         12    12         Kern County  1952   721  1153
# ...

# %%
sheet1.describe()
# Out:
#        Record Sequence Number          EQID          YEAR          MODY  \
# count             21539.00000  21539.000000  21539.000000  21539.000000
# mean              10770.00000    733.203816   2001.916663    687.493988
# std                6217.91806    442.741878     68.146129    318.488140
# min                   1.00000   -999.000000   -999.000000   -999.000000
# 25%                5385.50000    180.000000   2001.000000    502.000000
# 50%               10770.00000   1018.000000   2005.000000    716.000000
# 75%               16154.50000   1096.000000   2008.000000    925.000000
# max               21539.00000   1266.000000   2011.000000   1229.000000
#
#                HRMN  Station Sequence Number  Earthquake Magnitude  \
# count  21539.000000             21539.000000          21539.000000
# mean    1055.300617             50298.395608              4.397675
# std      888.797365             49198.528467             23.724577
# ...

# %%
print(type(sheet1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
sheet1.groupby('Earthquake Magnitude').size()
# Out:
# Earthquake Magnitude
# -999.00     12
#  2.99        5
#  3.01        6
#  3.02        1
#  3.05       33
#  3.07        3
#  3.08       24
#  3.09       18
#  3.14       73
#  3.16        5
#  3.17        9
#  3.19       11
#  3.20       31
#  3.22       19
#  3.23        7
#  3.25       25
#  3.27        6
#  3.28        7
#  3.29        8
#  3.30       31
#  3.31        1
#  3.32        2
#  3.34       27
#  3.36        4
#  3.37       33
#  3.39       20
#  3.40      188
#  3.41      105
#  3.43       96
#  3.45       35
#           ...
#  6.54       11
#  6.60       28
#  6.61      458
#  6.63      536
#  6.69      161
#  6.70       38
#  6.76        3
#  6.77        1
#  6.80      618
#  6.88        8
#  6.90      404
#  6.93       84
#  6.95        1
#  7.00      114
#  7.01       14
#  7.10       11
#  7.13      131
#  7.14       26
#  7.20      366
#  7.21        1
#  7.28       78
#  7.30       36
#  7.35        7
#  7.36        4
#  7.37        8
#  7.51       32
# ...

# %%
sheet1.head()
# Out:
#    Record Sequence Number  EQID     Earthquake Name  YEAR  MODY  HRMN  \
# 0                       1     1  Helena, Montana-01  1935  1031  1838
# 1                       2     2  Helena, Montana-02  1935  1031  1918
# 2                       3     3         Humbolt Bay  1937   207   442
# 3                       4     4  Imperial Valley-01  1938   606   242
# 4                       5     5  Northwest Calif-01  1938   912   610
#
#          Station Name  Station Sequence Number Station ID  No.  \
# 0     Carroll College                      197            2022
# 1     Helena Fed Bldg                      198            2229
# 2  Ferndale City Hall                      133            1023
# 3  El Centro Array #9                       75             117
# 4  Ferndale City Hall                      133            1023
#
#    Earthquake Magnitude    ...     Instrument Nat. Freq.  Instrument Damping  \
# 0                   6.0    ...                    -999.0              -999.0
# ...

# %%
sheet1.tail()
# Out:
#        Record Sequence Number  EQID Earthquake Name  YEAR  MODY  HRMN  \
# 21534                   21535  1265        51177103  2006  1223   649
# 21535                   21536  1265        51177103  2006  1223   649
# 21536                   21537  1265        51177103  2006  1223   649
# 21537                   21538  1265        51177103  2006  1223   649
# 21538                   21539  1265        51177103  2006  1223   649
#
#                                          Station Name  \
# 21534  Jasper Ridge Biol. Preserve, Stanford, CA, USA
# 21535                                San Andreas Cal.
# 21536                              Stanford Telescope
# 21537                                San Pedro Valley
# 21538                                    Point Molate
#
#        Station Sequence Number Station ID  No.  Earthquake Magnitude  ...    \
# 21534                   100506            JRSC                   3.6  ...
# ...

# %%
sheet1[4:10]
# Out:
#    Record Sequence Number  EQID     Earthquake Name  YEAR  MODY  HRMN  \
# 4                       5     5  Northwest Calif-01  1938   912   610
# 5                       6     6  Imperial Valley-02  1940   519   437
# 6                       7     7  Northwest Calif-02  1941   209   945
# 7                       8     8   Northern Calif-01  1941  1003  1614
# 8                       9     9             Borrego  1942  1021  1622
# 9                      10    10  Imperial Valley-03  1951   124   717
#
#          Station Name  Station Sequence Number Station ID  No.  \
# 4  Ferndale City Hall                      133            1023
# 5  El Centro Array #9                       75             117
# 6  Ferndale City Hall                      133            1023
# 7  Ferndale City Hall                      133            1023
# 8  El Centro Array #9                       75             117
# 9  El Centro Array #9                       75             117
#
# ...

# %%
y1 = sheet1[["Record Sequence Number", "Magnitude Type"]]
print(y1)
# Out:
#        Record Sequence Number Magnitude Type
# 0                           1             Mw
# 1                           2              U
# 2                           3             Mw
# 3                           4              U
# 4                           5             Mw
# 5                           6             Mw
# 6                           7              U
# 7                           8              U
# 8                           9              U
# 9                          10              U
# 10                         11             Mw
# 11                         12             Mw
# 12                         13             Mw
# 13                         14             Mw
# 14                         15             Mw
# 15                         16             Mw
# 16                         17              U
# 17                         18              U
# 18                         19              U
# 19                         20              U
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import operator
from operator import itemgetter

wb_sales = pd.ExcelFile(r"E:\Dhananjay Study\Masters Folder\Datasets of Ground Motion Spectrum Project\NGA_West2_Flatfile_RotD50_d050_public_version.xlsx")

print('dj2')

sheet1 = pd.read_excel(r"E:\Dhananjay Study\Masters Folder\Datasets of Ground Motion Spectrum Project\NGA_West2_Flatfile_RotD50_d050_public_version.xlsx", sheetname=0)
read_sheet_name = wb_sales.sheet_names
read_sheet_name


X_train = np.array(sheet1)
print(X_train.shape)

num_test = X_train.shape[0]
eq_mag = 6.0
m_type = "Mw"
rake_ang = 0.0
r_jb_dist = 4.5
vs_30 = 400
r_rupt = 10

list_of_ground = {}


for i in range(num_test):
    eq_mag1 = X_train[i][9]
    m_type1 = X_train[i][10]
    rake_ang1 = X_train[i][19]
    r_jb_dist1 = X_train[i][50]
    vs_301 = X_train[i][81]
    r_rupt1 = X_train[i][53]
    if(m_type1 == m_type ):
       # print(i, abs(eq_mag1 - eq_mag), abs(rake_ang1 - rake_ang), abs(r_jb_dist1 - r_jb_dist), abs(vs_301 - vs_30), abs(r_rupt-r_rupt1))
        dist1 = ((eq_mag1 - eq_mag) ** (2)) + ((rake_ang1 - rake_ang) ** (2)) + ((r_jb_dist1 - r_jb_dist) ** 2) + ((vs_301 - vs_30) ** (2)) + ((r_rupt-r_rupt1) ** (2))
        dist2 = (dist1) ** (1/2)
        list_of_ground[i] = dist2
        
dj1 = (sorted(list_of_ground.items(), key=operator.itemgetter(1)))

list1_of_k = [11, 22, 30 , 50] 
sheet2 =[]

for j in list1_of_k:
    print("Value of k is:", j)
    print(" ")
    for i in range(j):
        a1 = dj1[i][0]
        print("%d is" %(i+1), a1)
        print(" ")

for j in range(30):
    a1 = dj1[j][0]
    sheet2.append(X_train[a1])
    

print(len(sheet2))
# Out:
# dj2
# C:\Users\DHANANJAY\Anaconda3\envs\cs231n\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# (21539, 274)
# Value of k is: 11
#
# 1 is 2882
#
# 2 is 3247
#
# 3 is 2880
#
# 4 is 3162
#
# 5 is 2881
#
# 6 is 2901
#
# 7 is 3169
#
# 8 is 2337
#
# 9 is 3485
#
# 10 is 3224
#
# 11 is 2599
#
# Value of k is: 22
#
# 1 is 2882
#
# 2 is 3247
#
# 3 is 2880
#
# 4 is 3162
#
# 5 is 2881
#
# 6 is 2901
#
# 7 is 3169
#
# 8 is 2337
#
# 9 is 3485
#
# 10 is 3224
#
# 11 is 2599
#
# 12 is 1357
#
# 13 is 1524
#
# 14 is 2262
#
# 15 is 2589
#
# 16 is 3546
#
# 17 is 1449
#
# 18 is 1432
#
# 19 is 2691
#
# 20 is 3227
#
# 21 is 2270
#
# 22 is 2296
#
# Value of k is: 30
#
# 1 is 2882
#
# 2 is 3247
#
# 3 is 2880
#
# 4 is 3162
#
# 5 is 2881
#
# 6 is 2901
#
# 7 is 3169
#
# 8 is 2337
#
# 9 is 3485
#
# 10 is 3224
#
# 11 is 2599
#
# 12 is 1357
#
# 13 is 1524
#
# 14 is 2262
#
# 15 is 2589
#
# 16 is 3546
#
# 17 is 1449
#
# 18 is 1432
# ...

# %%
import pandas as pd
sheet2 = pd.DataFrame(sheet2)
sheet2 = sheet2[[9, 10 , 19, 50, 53, 81]]
print(sheet2)
# Out:
#       9   10  19     50     53          81
# 0   6.20  Mw   0 -999.0   5.39  406.589002
# 1   6.20  Mw   2 -999.0  19.50  398.455059
# 2   6.20  Mw   0 -999.0   3.59  391.234581
# 3   6.20  Mw   2 -999.0  11.60  410.849447
# 4   6.20  Mw   0 -999.0   1.98  390.424579
# 5   6.20  Mw   0 -999.0   7.78  413.006620
# 6   6.20  Mw   2 -999.0   6.02  412.631756
# 7   5.90  Mw   2 -999.0   5.96  413.205951
# 8   6.30  Mw   2 -999.0  -4.03  399.432558
# 9   6.20  Mw   2 -999.0   3.46  413.006620
# 10  6.20  Mw   2 -999.0   2.09  412.631756
# 11  7.62  Mw   3 -999.0  24.63  402.439689
# 12  7.62  Mw   3 -999.0  -6.01  399.432558
# 13  5.90  Mw   2 -999.0   9.28  382.763568
# 14  6.20  Mw   2 -999.0  -3.83  410.849447
# 15  6.30  Mw   2 -999.0  23.98  388.149577
# 16  7.62  Mw   3 -999.0  27.84  404.116824
# 17  7.62  Mw   3 -999.0  24.43  388.145373
# 18  6.20  Mw   2 -999.0  24.77  388.149577
# 19  6.20  Mw   2 -999.0  25.19  386.139122
# 20  5.90  Mw   2 -999.0  21.74  383.111117
# ...

# %%
import pandas as pd
dj2 = pd.DataFrame(sheet2)
dj3 = dj2[[9, 10 , 19, 50, 81, 53]]

dj1 = np.array(sheet2[[9]])
dj21 = np.array(sheet2[[10]])

print("dj3 is:", dj3)
print(" ")
print(dj2)
a1 = dj2.groupby(9).size()
b1 = dj2.groupby(10).size()
print(b1)

feature_columns = [9, 19, 50, 81, 53]
X_dataset = np.array(dj2[feature_columns].values)
y_dataset = np.array(dj2[10].values)

print(X_dataset1)

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y_dataset)

print('dj1')

import matplotlib.pyplot as plt
import seaborn as sns

from pandas.plotting import parallel_coordinates
plt.figure(figsize=(15,10))
parallel_coordinates(dj1, dj21)
plt.title('Parallel Coordinates Plot', fontsize=20, fontweight='bold')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Features values', fontsize=15)
plt.legend(loc=1, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")
plt.show()
# Out:
# dj3 is:       9   10  19     50          81     53
# 0   6.20  Mw   0 -999.0  406.589002   5.39
# 1   6.20  Mw   2 -999.0  398.455059  19.50
# 2   6.20  Mw   0 -999.0  391.234581   3.59
# 3   6.20  Mw   2 -999.0  410.849447  11.60
# 4   6.20  Mw   0 -999.0  390.424579   1.98
# 5   6.20  Mw   0 -999.0  413.006620   7.78
# 6   6.20  Mw   2 -999.0  412.631756   6.02
# 7   5.90  Mw   2 -999.0  413.205951   5.96
# 8   6.30  Mw   2 -999.0  399.432558  -4.03
# 9   6.20  Mw   2 -999.0  413.006620   3.46
# 10  6.20  Mw   2 -999.0  412.631756   2.09
# 11  7.62  Mw   3 -999.0  402.439689  24.63
# 12  7.62  Mw   3 -999.0  399.432558  -6.01
# 13  5.90  Mw   2 -999.0  382.763568   9.28
# 14  6.20  Mw   2 -999.0  410.849447  -3.83
# 15  6.30  Mw   2 -999.0  388.149577  23.98
# 16  7.62  Mw   3 -999.0  404.116824  27.84
# 17  7.62  Mw   3 -999.0  388.145373  24.43
# 18  6.20  Mw   2 -999.0  388.149577  24.77
# 19  6.20  Mw   2 -999.0  386.139122  25.19
# 20  5.90  Mw   2 -999.0  383.111117  21.74
# ...

# %%
from pandas.plotting import parallel_coordinates
plt.figure(figsize=(15,10))
parallel_coordinates(.drop("Id", axis=1), "Species")
plt.title('Parallel Coordinates Plot', fontsize=20, fontweight='bold')
plt.xlabel('Features', fontsize=15)
plt.ylabel('Features values', fontsize=15)
plt.legend(loc=1, prop={'size': 15}, frameon=True,shadow=True, facecolor="white", edgecolor="black")
plt.show()

# %%
class NearestNeighbor(object):
    def __init__(self):
        pass
    
    def train(self,X,Y):
        self.Xtr = X
        self.Ytr = Y
    
    def predict(self,X,k=1):
        num_test = X.shape[0]
            
        Y_pred = np.zeros(num_test, dtype=self.Ytr.dtype)
        
        for i in range(num_test):
            distances = np.sum(np.abs(self.Xtr - X[i,:]), axis = 1)
            index1 = np.argmin(distances)
            Y_pred[i] = self.Ytr[index1]
            
        return Y_pred
    
    def compute_distance_two_loops(self,X):
        num_test1 = X.shape[0]
        num_train1 = self.Xtr.shape[0]
        dists = np.zeros((num_test1 , num_train1))
        print(dists.shape)
        for i in range(num_test1):
            for j in range(num_train1):
                distance = np.sum(np.abs(self.Xtr[j,:] -X[i,:]))
                dists[i,j]=distance
                
        return dists
    
    def compute_distance_one_loops(self,X):
        num_test1 = X.shape[0]
        num_train1 = self.Xtr.shape[0]
        dists = np.zeros((num_test1, num_train1))
        for i in range(num_test1):
            distances = np.sqrt(np.sum(np.square(self.Xtr - X[i,:]), axis=1))
            dists[i,:] = distances
        
        return dists
    
    def compute_distance_with_no_loops(self,X):
        num_test1 = X.shape[0]
        num_train1 = self.Xtr.shape[0]
        dists = np.zeros((num_test1, num_train1))
        
        dists = np.sqrt((X**2).sum(axis=1, keepdims = True) + (self.Xtr**2).sum(axis=1) - 2*X.dot(self.Xtr.T))
        return dists
    
    def predict_labels(self,dists,k=1):
        num_tests = dists.shape[0]
        y_pred = np.zeros(num_tests)
        for i in range(num_tests):
            closest = []
            closest = self.Ytr[np.argsort(dists[i])][:k]
            print(" ")
            y_pred[i] = np.argmax(np.bincount(closest))
            
        return y_pred

# %%
class NearestNeighbor(object):
    def __init__(self):
        pass
    
    def train(self,X,Y):
        self.Xtr = X
        self.Ytr = Y
        
    def predict(self,X,k=1):
        num_test = X.shape[0]
        Y_pred = np.zeros(num_test, dtype = self.Ytr.dtype)
        print(num_test)
        for i in range(num_test):
            distances = np.sum(np.abs(self.Xtr-X[i,:]), axis=1)
            min_index = np.argmin(distances)
            print(min_index)
            Y_pred[i] = self.Ytr[min_index]
        
        return Y_pred
